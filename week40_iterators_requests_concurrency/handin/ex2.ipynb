# %%
import pandas as pd 
# %run Books.py

book_names, vowels = Books.hardest_read()
d = {'Book': book_names, 'Vowels': vowels}
df = pd.DataFrame(d).sort_values('Vowels', ascending=False)

display(df)
df.plot(kind="bar", x='Book', y='Vowels', figsize=(10,4))
# Out:
#                   Book  Vowels
# 9  pride_and_prejudice  209876
# 4       Scarlet_letter  150192
# 3         Frankenstein  133076
# 8    Life_of_Frederick   72279
# 0              Beowulf   71832
# 2     Alice_Adventures   47548
# 1           doll_house   46571
# 6               Anthem   34023
# 7     Yellow_WallPaper   15121
# 5      Modest_Proposal   11818
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x7fbe563384d0&gt;
# &lt;Figure size 720x288 with 1 Axes&gt;
