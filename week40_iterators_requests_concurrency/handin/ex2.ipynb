# %%
import pandas as pd 
# %run Books.py

book_names, vowels = Books.hardest_read()
d = {'Book': book_names, 'Vowels': vowels}
df = pd.DataFrame(d).sort_values('Vowels', ascending=False)

display(df)
df.plot(kind="bar", x='Book', y='Vowels', figsize=(10,4))
# Out:
#                   Book    Vowels
# 5      Modest_Proposal  1.961819
# 7     Yellow_WallPaper  1.818083
# 3         Frankenstein  1.813766
# 4       Scarlet_letter  1.797523
# 8    Life_of_Frederick  1.767386
# 1           doll_house  1.735716
# 2     Alice_Adventures  1.731537
# 9  pride_and_prejudice  1.140680
# 6               Anthem  1.110883
# 0              Beowulf  1.016227
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x7fbe3ce5bcd0&gt;
# &lt;Figure size 720x288 with 1 Axes&gt;
